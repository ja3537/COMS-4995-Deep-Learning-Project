# %%
import os
import sys
from eval import get_metrics

# %%
# Edit paths so list1 points to the validation set ground truth images and
# and list2 points to the images generated by a trained model 
list1 = []
list2 = []
for i in range(1305,1450):
    list1.append(f"C:\\Users\\Michael\\Documents\\COMS-4995-Deep-Learning-Project\\validation_set\\validation_{i}_rgb.png")
    list2.append(f"C:\\Users\Michael\\Documents\\COMS-4995-Deep-Learning-Project\\Deep-Red-Flash-main\\image_filtering\\output_380_a\\out_{i}.png")

# %%
psnr, ssim, vgg = get_metrics(list1, list2)

# %%
print(f"psnr: {psnr}, ssim: {ssim}, vgg: {vgg}")
# Out:
# psnr: 4.7528461094230865, ssim: 0.6806065206114311, vgg: 11.171468734741211
